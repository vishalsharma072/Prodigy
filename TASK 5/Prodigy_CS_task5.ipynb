# %%
pip install scapy
# Out:
# Collecting scapyNote: you may need to restart the kernel to use updated packages.
#
#   Using cached scapy-2.5.0.tar.gz (1.3 MB)
# Building wheels for collected packages: scapy
#   Building wheel for scapy (setup.py): started
#   Building wheel for scapy (setup.py): finished with status 'done'
#   Created wheel for scapy: filename=scapy-2.5.0-py2.py3-none-any.whl size=1444335 sha256=4eb17f8fe997b6ddfacb12d21d283ccb84f9515ddf82ac51f46ff0875946f182
#   Stored in directory: c:\users\visha\appdata\local\pip\cache\wheels\98\ea\08\164e840ab2c83b892bf8b193ce9d92d029dc3e5f2b75319953
# Successfully built scapy
# Installing collected packages: scapy
# Successfully installed scapy-2.5.0

# %%
pip install scapy
# Out:
# Requirement already satisfied: scapy in c:\users\visha\anaconda3\lib\site-packages (2.5.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from scapy.all import sniff, IP, TCP, UDP, ICMP

def packet_callback(packet):
    print(f"Packet received: {packet.summary()}")

    if IP in packet:
        src_ip = packet[IP].src
        dst_ip = packet[IP].dst
        
        print(f"Source IP: {src_ip}")
        print(f"Destination IP: {dst_ip}")

        if TCP in packet:
            print("Protocol: TCP")
        elif UDP in packet:
            print("Protocol: UDP")
        elif ICMP in packet:
            print("Protocol: ICMP")
        else:
            print("Protocol: Other")


        payload = packet.payload
        if payload:
            print(f"Payload Data (hex): {payload.original.hex()}")
            print(f"Payload Data (ascii): {payload.original.decode(errors='ignore')}")


def main():
            print("Starting packet sniffer...")
sniff(prn=packet_callback, store=0, filter="ip", count=10)  


if __name__ == "__main__":
    
    main()
# Out:
# Packet received: Ether / IP / UDP / DNS Ans "b'Android-2.local.'"
# Source IP: 10.11.1.158
# Destination IP: 224.0.0.251
# Protocol: UDP
# Payload Data (hex): ...
# Payload Data (ascii): E_@/.
# ]15811110in-addrarpax	Android-2local8C317869B2288F2700000000000008EFip6 x00x
# 0xr+/xA/xA0/x0@
# Packet received: Ether / IP / TCP 10.11.1.22:58057 > 10.9.0.222:ms_do S
# Source IP: 10.11.1.22
# Destination IP: 10.9.0.222
# Protocol: TCP
# Payload Data (hex): 4500003439744000800600000a0b01160a0900dee2c91e00a5be1e96000000008002faf0162e0000020405b40103030801010402
# Payload Data (ascii): E49t@
#
# 	.
# Packet received: Ether / IP / TCP 10.11.1.22:58056 > 10.4.0.206:ms_do S
# Source IP: 10.11.1.22
# Destination IP: 10.4.0.206
# Protocol: TCP
# Payload Data (hex): 450000348dad4000800600000a0b01160a0400cee2c81e006201c1cf000000008002faf016190000020405b40103030801010402
# Payload Data (ascii): E4@
#
# b
# Packet received: Ether / IP / UDP / DNS Ans "b'rj._rc._tcp.local.'"
# Source IP: 10.11.1.2
# Destination IP: 224.0.0.251
# Protocol: UDP
# Payload Data (hex): ...
# Payload Data (ascii): Em@
# k6_rc_tcplocalxrj&!xmilink504504411&xprotver=16777510prottext=RC Ver 1.0.1.38platform_id=2005
# scrnw=1920
# scrnh=1080mac=3c:2c:a6:72:9d:82serverport=6088photoport=6089rid=-1apmac=58:61:63:00:94:fd
# operator=1miversion=unknownwol=0amac=dc:97:58:63:4f:f3CP=[130751]VC=0btmac=dc:97:58:63:4f:f4
# Packet received: Ether / IP / ICMP 103.124.175.226 > 10.11.1.22 dest-unreach host-unreachable / IPerror / TCPerror
# Source IP: 103.124.175.226
# Destination IP: 10.11.1.22
# Protocol: ICMP
# Payload Data (hex): 45c0005094b500004001c2b8677cafe20a0b01160301132d0000000045000034397440007f06ac480a0b01160a0900dee2c91e00a5be1e96000000008002faf098f90000020405b40103030801010402
# Payload Data (ascii): EP@¸g|
# -E49t@H
#
#
# Packet received: Ether / IP / ICMP 103.124.175.226 > 10.11.1.22 dest-unreach host-unreachable / IPerror / TCPerror
# Source IP: 103.124.175.226
# Destination IP: 10.11.1.22
# Protocol: ICMP
# Payload Data (hex): 45c0005094b600004001c2b7677cafe20a0b01160301131800000000450000348dad40007f0658240a0b01160a0400cee2c81e006201c1cf000000008002faf039930000020405b40103030801010402
# Payload Data (ascii): EP@·g|
# E4@X$
#
# b9
# Packet received: Ether / IP / TCP 10.11.1.22:64822 > 216.58.196.106:https A / Raw
# Source IP: 10.11.1.22
# Destination IP: 216.58.196.106
# Protocol: TCP
# Payload Data (hex): 45000029be6d4000800600000a0b0116d83ac46afd3601bb8c69c09446d5515d50100200a7e1000000
# Payload Data (ascii): E)m@
# :j6iFQ]P
# Packet received: Ether / IP / TCP 216.58.196.106:https > 10.11.1.22:64822 A
# Source IP: 216.58.196.106
# Destination IP: 10.11.1.22
# Protocol: TCP
# Payload Data (hex): 4580003450e000007a06479ed83ac46a0a0b011601bbfd3646d5515d8c69c0958010011b52bb00000101050a8c69c0948c69c095
# Payload Data (ascii): E4PzG:j
# 6FQ]iR
# ii
# Packet received: Ether / IP / UDP / DNS Qry "b'_companion-link._tcp.local.'"
# Source IP: 10.11.0.183
# Destination IP: 224.0.0.251
# Protocol: UDP
# Payload Data (hex): 4500007fa6130000ff11299d0a0b00b7e00000fb14e914e9006bf29a0000000000040000000000000f5f636f6d70616e696f6e2d6c696e6b045f746370056c6f63616c00000c8001075f72646c696e6bc01c000c8001026c62075f646e732d7364045f756470c021000c80010c5f736c6565702d70726f7879c045000c8001
# Payload Data (ascii): E)
# k_companion-link_tcplocal_rdlinklb_dns-sd_udp!_sleep-proxyE
# Packet received: Ether / IP / UDP / DNS Qry "b'_companion-link._tcp.local.'"
# Source IP: 10.11.0.183
# Destination IP: 224.0.0.251
# Protocol: UDP
# Payload Data (hex): 4500007fa2ab0000ff112d050a0b00b7e00000fb14e914e9006b731c0000000000040000000000000f5f636f6d70616e696f6e2d6c696e6b045f746370056c6f63616c00000c0001075f72646c696e6bc01c000c0001026c62075f646e732d7364045f756470c021000c00010c5f736c6565702d70726f7879c045000c0001
# Payload Data (ascii): E-
# ks_companion-link_tcplocal_rdlinklb_dns-sd_udp!_sleep-proxyE
# Starting packet sniffer...

# %%
from scapy.all import sniff, IP, TCP, UDP, ICMP

def packet_callback(packet):
    print(f"Packet received: {packet.summary()}")

    if IP in packet:
        src_ip = packet[IP].src
        dst_ip = packet[IP].dst
        
        print(f"Source IP: {src_ip}")
        print(f"Destination IP: {dst_ip}")

        if TCP in packet:
            print("Protocol: TCP")
        elif UDP in packet:
            print("Protocol: UDP")
        elif ICMP in packet:
            print("Protocol: ICMP")
        else:
            print("Protocol: Other")


        payload = packet.payload
        if payload:
            print(f"Payload Data (hex): {payload.original.hex()}")
            print(f"Payload Data (ascii): {payload.original.decode(errors='ignore')}")


def main():
            print("Starting packet sniffer...")
sniff(prn=packet_callback, store=0, filter="ip", count=10)  


if __name__ == "__main__":
    
    main()
# Out:
# Packet received: Ether / IP / TCP 10.11.1.22:49392 > 13.107.21.239:https PA / Raw
# Source IP: 10.11.1.22
# Destination IP: 13.107.21.239
# Protocol: TCP
# Payload Data (hex): 
# Payload Data (ascii): E@
# k!rz"P.c
# yCJ 7㞄h
# >AL%Sbs&]RdlCz:K*HPoQdć,sl
# Packet received: Ether / IP / TCP 10.11.1.22:49392 > 13.107.21.239:https PA / Raw
# Source IP: 10.11.1.22
# Destination IP: 13.107.21.239
# Protocol: TCP
# Payload Data (hex): 45000056d31a4000800600000a0b01160d6b15efc0f001bb21c5727c7aa022fe501802002ec300001703030029000000000000000b7c75b0c99e33178decb11af308a67434267aefa1488c66a5fc552797f742c3da96
# Payload Data (ascii): EV@
# k!r|z"P.)|uɞ3t4&zHfU'Bږ
# Packet received: Ether / IP / UDP / BOOTP / DHCP Ack
# Source IP: 10.11.0.1
# Destination IP: 255.255.255.255
# Protocol: UDP
# Payload Data (hex): ...
# Payload Data (ascii): EH
# CD43U
# S
# S
# W~ cSc5
# 36
#
# Packet received: Ether / IP / TCP 13.107.21.239:https > 10.11.1.22:49392 A / Padding
# Source IP: 13.107.21.239
# Destination IP: 10.11.1.22
# Protocol: TCP
# Payload Data (hex): 450000284d4a40007806870b0d6b15ef0a0b011601bbc0f07aa022fe21c572aa50103ffc4ca40000000000000000
# kyload Data (ascii): E(MJ@x
# z"!rP?L
# Packet received: Ether / IP / TCP 13.107.21.239:https > 10.11.1.22:49392 PA / Raw
# Source IP: 13.107.21.239
# Destination IP: 10.11.1.22
# Protocol: TCP
# Payload Data (hex): 450000564d4b4000780686dc0d6b15ef0a0b011601bbc0f07aa022fe21c572aa50183ffcb5e200001703030029000000000000000b1e9e68e35ddbd21bfb810d4ed516b39572643d543a37bd91e0b9bf42c37d2e5706
# kyload Data (ascii): EVMK@x
# Nrd=T:7๿B}.W)h]
# Packet received: Ether / IP / TCP 10.11.1.22:49392 > 13.107.21.239:https A
# Source IP: 10.11.1.22
# Destination IP: 13.107.21.239
# Protocol: TCP
# Payload Data (hex): 45000028d31b4000800600000a0b01160d6b15efc0f001bb21c572aa7aa0232c501002002e950000
# Payload Data (ascii): E(@
# k!rz#,P.
# Packet received: Ether / IP / TCP 13.107.21.239:https > 10.11.1.22:49392 PA / Raw
# Source IP: 13.107.21.239
# Destination IP: 10.11.1.22
# Protocol: TCP
# Payload Data (hex): 450000564d4c4000770687db0d6b15ef0a0b011601bbc0f07aa022fe21c572aa50183ffcb5e200001703030029000000000000000b1e9e68e35ddbd21bfb810d4ed516b39572643d543a37bd91e0b9bf42c37d2e5706
# kyload Data (ascii): EVML@w
# Nrd=T:7๿B}.W)h]
# Packet received: Ether / IP / TCP 13.107.21.239:https > 10.11.1.22:49392 PA / Raw
# Source IP: 13.107.21.239
# Destination IP: 10.11.1.22
# Protocol: TCP
# Payload Data (hex): ...
# kyload Data (ascii): EMM@xW
# {5.U/`ycC,:6d_Fq}؛"XCE46UhL|޹^#Ou(tж;5D{k$GpF{	%X{8~ģ+x2a9f2n[
# Packet received: Ether / IP / TCP 13.107.21.239:https > 10.11.1.22:49392 PA / Raw
# Source IP: 13.107.21.239
# Destination IP: 10.11.1.22
# Protocol: TCP
# Payload Data (hex): 4500004e4d4e4000780686e10d6b15ef0a0b011601bbc0f07aa023dd21c572aa50183ffc2c4400001703030021000000000000000d19ed4c5b69cde6bd6b692e0931789b7276a4ba97801bc64dbb
# kyload Data (ascii): ENMN@x
# L[iki.	1xrvM!
# Packet received: Ether / IP / TCP 10.11.1.22:49392 > 13.107.21.239:https A
# Source IP: 10.11.1.22
# Destination IP: 13.107.21.239
# Protocol: TCP
# Payload Data (hex): 45000034d31c4000800600000a0b01160d6b15efc0f001bb21c572aa7aa0232c801002002ea100000101050a7aa022fe7aa0232c
# Payload Data (ascii): E4@
# k!rz#,.
# z"z#,
# Starting packet sniffer...
